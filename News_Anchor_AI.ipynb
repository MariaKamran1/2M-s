# %%
# !pip install -U google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key="GOOGLE_API_KEY_2")
model = genai.GenerativeModel("models/gemini-1.5-flash")

# %%
# Step 1: Install Libraries (Only run once)
# !pip install -U google-generativeai newspaper3k gTTS

# %%
# Step 2: Import Libraries
import google.generativeai as genai
from newspaper import Article
from gtts import gTTS
import IPython.display as ipd

# %%
# Step 3: Configure Gemini
genai.configure(api_key="GOOGLE_API_KEY_2")
model = genai.GenerativeModel("models/gemini-1.5-flash")

# %%
# Step 4: Scrape a News Article
url = "https://www.dawn.com/news/1830171"
article = Article(url)
article.download()
article.parse()
print(article.text[:700])  # Preview first few lines
# Out:
# Pakistan is grappling with its highest inflation rate in almost half a century. Over recent months, inflation has surged to as much as 38 per cent, marking the highest rate in South Asia. Food inflation has skyrocketed to 48pc, reaching its highest level since 2016.
#
# The government significantly devalued the currency by more than 50pc within a year and eliminated subsidies as part of the latest instalment of the International Monetary Fund bailout package. Consequently, the nation is facing a severe cost-of-living crisis.
#
# In a country where economic challenges often overshadow the daily lives of its citizens, the concept of fair wages has emerged as a beacon of hope. Pakistan, like many dev

# %%
import google.generativeai as genai

genai.configure(api_key="GOOGLE_API_KEY_2")
model = genai.GenerativeModel("models/gemini-1.5-flash")  # or "models/gemini-1.5-pro" if you enabled that

# %%
news_script = """Pakistan's energy sector is rapidly transitioning toward renewable sources.
Government incentives have led to a spike in solar installations nationwide.
Experts predict a 30% increase in clean energy by the end of 2025.
"""
print(news_script)
# Out:
# Pakistan's energy sector is rapidly transitioning toward renewable sources.
# Government incentives have led to a spike in solar installations nationwide.
# Experts predict a 30% increase in clean energy by the end of 2025.

# %%
tts = gTTS(news_script, lang='en')
tts.save("news.mp3")
ipd.display(ipd.Audio("news.mp3"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
